# %% [markdown]
# ##### Google Colab Notebook
# # DistilBERT with Rating
# ## Inputs: Review + Rating

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from google.colab import drive

# This will prompt you to click on a link and get an authentication code
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from tqdm.auto import tqdm
import numpy as np

import textstat
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import tensorflow as tf
from transformers import DistilBertTokenizer, TFDistilBertModel
from tensorflow.keras import layers, Input, Model
# Out:
# Collecting textstat
#   Downloading textstat-0.7.3-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 kB 3.8 MB/s eta 0:00:00
# Collecting pyphen (from textstat)
#   Downloading pyphen-0.14.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 20.1 MB/s eta 0:00:00
# Installing collected packages: pyphen, textstat
# Successfully installed pyphen-0.14.0 textstat-0.7.3

# %%
# Pandas Progress bar
tqdm.pandas()

# %%
dataset_path = '/content/drive/My Drive/Datasets/Modified_Books_rating.csv'
df = pd.read_csv(dataset_path)

# %%
df.head()
# Out:
#                                Title helpful  Rating  \
# 0                   Alaska Sourdough   36/37     5.0
# 1                   Alaska Sourdough   29/30     5.0
# 2                   Alaska Sourdough   25/28     5.0
# 3  Eyewitness Travel Guide to Europe    3/20     1.0
# 4  Eyewitness Travel Guide to Europe   20/20     5.0
#
#                                Title.1  \
# 0               Real Alaskan Sourdough
# 1                 True Alaskan cooking
# 2  Cheechako to Sourdough in 190 Pages
# 3               Disappointed Romanian!
# 4      Going to Europe? Get this book!
#
#                                               Review  helpful_0  helpful_1  \
# 0  Ruth Allman has written an excellent book abou...         36         37
# 1  I have been using this book since 1988, the ei...         29         30
# 2  My poor dogeared, stained copy of this book ca...         25         28
# 3  This book in my opinion is biased and takes an...          3         20
# 4  If you're already a fan of the Eyewitness Trav...         20         20
#
#    ratio_percent  review_len  IsHelpful  \
# 0             97         153          1
# 1             96          63          1
# 2             89         206          1
# 3             15          92          0
# 4            100         234          1
#
#                                      cleaned_reviews
# 0  ruth allman written excellent book alaskan sou...
# 1  i using book since eighth printing i honestly ...
# 2  my poor dogeared stained copy book came way da...
# 3  this book opinion biased take angle europe cle...
# 4  if youre already fan eyewitness travel guide s...

# %%
# Normalize Review Length
from sklearn.preprocessing import MinMaxScaler

# Assuming you have a DataFrame 'df' with a column 'review_len'
scaler = MinMaxScaler()

# Reshape the data to be a 2D array if it's a single feature
df['rating_normalized'] = scaler.fit_transform(df['Rating'].values.reshape(-1, 1))

# %%
df.head()
# Out:
#                                Title helpful  Rating  \
# 0                   Alaska Sourdough   36/37     5.0
# 1                   Alaska Sourdough   29/30     5.0
# 2                   Alaska Sourdough   25/28     5.0
# 3  Eyewitness Travel Guide to Europe    3/20     1.0
# 4  Eyewitness Travel Guide to Europe   20/20     5.0
#
#                                Title.1  \
# 0               Real Alaskan Sourdough
# 1                 True Alaskan cooking
# 2  Cheechako to Sourdough in 190 Pages
# 3               Disappointed Romanian!
# 4      Going to Europe? Get this book!
#
#                                               Review  helpful_0  helpful_1  \
# 0  Ruth Allman has written an excellent book abou...         36         37
# 1  I have been using this book since 1988, the ei...         29         30
# 2  My poor dogeared, stained copy of this book ca...         25         28
# 3  This book in my opinion is biased and takes an...          3         20
# 4  If you're already a fan of the Eyewitness Trav...         20         20
#
#    ratio_percent  review_len  IsHelpful  \
# 0             97         153          1
# 1             96          63          1
# 2             89         206          1
# 3             15          92          0
# 4            100         234          1
#
#                                      cleaned_reviews  rating_normalized
# 0  ruth allman written excellent book alaskan sou...                1.0
# 1  i using book since eighth printing i honestly ...                1.0
# 2  my poor dogeared stained copy book came way da...                1.0
# 3  this book opinion biased take angle europe cle...                0.0
# 4  if youre already fan eyewitness travel guide s...                1.0

# %% [markdown]
# ### Model

# %%
# Split data
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# %%
# Tokenize the text using DistilBERT tokenizer
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')

train_text_tokens = tokenizer(list(train_df['Review']), padding=True, truncation=True, return_tensors='tf', max_length=512)
test_text_tokens = tokenizer(list(test_df['Review']), padding=True, truncation=True, return_tensors='tf', max_length=512)
# Out:
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]

# %%
# Define DistilBERT model
distilbert_model = TFDistilBertModel.from_pretrained('distilbert-base-uncased')
# Out:
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFDistilBertModel: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_transform.bias']
# - This IS expected if you are initializing TFDistilBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFDistilBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertModel for predictions without further training.

# %%
# Define input layers
input_text = Input(shape=(512,), name='input_text', dtype=tf.int32)
input_rating = Input(shape=(1,), name='input_rating', dtype=tf.float32)

# %%
# Token embeddings from DistilBERT
text_embeddings = distilbert_model(input_text).last_hidden_state[:, 0, :]

# %%
# Concatenate text and numerical features
combined_features = layers.concatenate([text_embeddings, input_rating])

# %%
# Dense layers for classification
x = layers.Dense(256, activation='relu')(combined_features)
output = layers.Dense(1, activation='sigmoid')(x)

# %%
# Build the model
model = Model(inputs=[input_text, input_rating], outputs=output)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# Prepare input data
train_inputs = {'input_text': train_text_tokens['input_ids'], 'input_rating': train_df['rating_normalized'].values}
test_inputs = {'input_text': test_text_tokens['input_ids'], 'input_rating': test_df['rating_normalized'].values}

# %%
# Train the model
model.fit(train_inputs, train_df['IsHelpful'].values, epochs=3, batch_size=8, validation_data=(test_inputs, test_df['IsHelpful'].values))
# Out:
# Epoch 1/3
# 18111/18111 [==============================] - 3142s 172ms/step - loss: 0.3647 - accuracy: 0.8409 - val_loss: 0.3137 - val_accuracy: 0.8666
# Epoch 2/3
# 18111/18111 [==============================] - 3119s 172ms/step - loss: 0.2640 - accuracy: 0.8905 - val_loss: 0.2934 - val_accuracy: 0.8737
# Epoch 3/3
# 18111/18111 [==============================] - 3115s 172ms/step - loss: 0.1808 - accuracy: 0.9273 - val_loss: 0.3234 - val_accuracy: 0.8793

# %%
# Save model so I don't have to do this again (hopefully)

# Save the model to a file
# this is temporarily saved on vm from Colab
model.save('/content/my_model')
# Out:
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.regularization.dropout.Dropout object at 0x7f3ee9bc9120>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.regularization.dropout.Dropout object at 0x7f3ee9bcbd00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.regularization.dropout.Dropout object at 0x7f3ee489a980>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.regularization.dropout.Dropout object at 0x7f3ee48f5600>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.regularization.dropout.Dropout object at 0x7f3ee4960280>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.regularization.dropout.Dropout object at 0x7f3ee4962ec0>, because it is not built.

# %%
# Save to Google Drive
model.save('/content/drive/MyDrive/Datasets/DistilBERT_Model_withRating')
# Out:
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.regularization.dropout.Dropout object at 0x7f3ee9bc9120>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.regularization.dropout.Dropout object at 0x7f3ee9bcbd00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.regularization.dropout.Dropout object at 0x7f3ee489a980>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.regularization.dropout.Dropout object at 0x7f3ee48f5600>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.regularization.dropout.Dropout object at 0x7f3ee4960280>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.regularization.dropout.Dropout object at 0x7f3ee4962ec0>, because it is not built.
