# %% [markdown]
# ### Imports
#
# Installiert benötigte Imports mit 'pip install ...'

# %%
import warnings
warnings.filterwarnings('ignore')

#General Data/Plotting
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
from tqdm.auto import tqdm 
import random
import re

# Add more later if necessary

# %%
df = pd.read_json('../Datasets/Cell_Phones_and_Accessories_5.json', lines=True)

# %%
# rename columns for better understanding
df = df.rename(columns={"reviewText":"Review","overall": "Rating","summary":"Title"})

# drop unessesary data
df.drop(['reviewerID', 'asin', 'reviewerName', 'unixReviewTime', 'reviewTime'], axis='columns', inplace=True)

# split the helpful tuple into two new rows
df['helpful_0'] = df['helpful'].apply(func=lambda x: x[0])
df['helpful_1'] = df['helpful'].apply(func=lambda x: x[1])

# Remove Reviews that have less than 2 helpful votes
df = df[df['helpful_1'] >= 2]

# add calculation of helpfullness ration and convert it to an int percentage
df['helpful_ratio'] = df['helpful_0'] / df['helpful_1']
df['ratio_percent'] = (df['helpful_ratio'] * 100).astype(int)

# calculate length of reviews in new column
df['review_len'] = [len(text.split()) for text in df.Review]

# %%
def convert_label(df) : 
    if df['ratio_percent'] <= 70 : 
        rate = 0 # for Negative 
    else : 
        rate = 1 # for Positive
        
    return rate

# %%
df['IsHelpful'] = df.apply(convert_label, axis = 1)
df.head()
# Out:
#   helpful                                             Review  Rating  \
# 3  [4, 4]  Item arrived in great time and was in perfect ...       4
# 4  [2, 3]  awesome! stays on, and looks great. can be use...       5
# 5  [1, 2]  These make using the home button easy. My daug...       3
# 7  [1, 2]  it worked for the first week then it only char...       1
# 8  [2, 3]  Good case, solid build. Protects phone all aro...       5
#
#                                        Title  helpful_0  helpful_1  \
# 3                                      Cute!          4          4
# 4  leopard home button sticker for iphone 4s          2          3
# 5                                       Cute          1          2
# 7                            not a good Idea          1          2
# 8                                 Solid Case          2          3
#
#    helpful_ratio  ratio_percent  review_len  IsHelpful
# 3       1.000000            100          51          1
# 4       0.666667             66          23          0
# 5       0.500000             50          23          0
# 7       0.500000             50          20          0
# 8       0.666667             66          44          0

# %% [markdown]
# df['Capslock_Count'] = df['Review'].str.findall(r'\b[A-Z]+\b')

# %%
df['Capslock_Count'] = df['Review'].str.findall(r'\b(?![Ii]\b)[A-Z]+\b').str.len()

# %%
df.head(20)
# Out:
#       helpful                                             Review  Rating  \
# 3      [4, 4]  Item arrived in great time and was in perfect ...       4
# 4      [2, 3]  awesome! stays on, and looks great. can be use...       5
# 5      [1, 2]  These make using the home button easy. My daug...       3
# 7      [1, 2]  it worked for the first week then it only char...       1
# 8      [2, 3]  Good case, solid build. Protects phone all aro...       5
# 11     [2, 3]  This is the first battery case I have had for ...       5
# 12     [3, 3]  Performs exactly as advertised . It's very  st...       5
# 13   [12, 16]  Unlike Most of the Rechargeable Battery cases,...       5
# 16     [2, 3]  It works great. Doesn't heat up like crazy lik...       5
# 18     [2, 3]  I have tested this against the griffin dual ou...       5
# 27     [3, 4]  This is a nice charger but you can tell it was...       4
# 31     [2, 3]  I've bough a munch of different things like th...       5
# 54     [3, 3]  I love this case! It's so pretty.And I love th...       5
# 74     [2, 2]  This is the cutest case EVER!  I love it becau...       5
# 88     [4, 4]  This Charger is awesome! First of all I wasn't...       5
# 143    [2, 3]  In a nutshell, this is NOT an OEM charger.  Al...       1
# 151    [2, 2]  Bought one for me and another for the wife. Ac...       5
# 154    [2, 2]  I was surprised it game in three steps, but wh...       5
# 155    [2, 2]  I was looking for something different to my wi...       5
# 160    [2, 2]  Great case for my phone. Protects and keeps me...       5
#
#                                                  Title  helpful_0  helpful_1  \
# 3                                                Cute!          4          4
# 4            leopard home button sticker for iphone 4s          2          3
# 5                                                 Cute          1          2
# 7                                      not a good Idea          1          2
# 8                                           Solid Case          2          3
# 11                                            A Winner          2          3
# 12                         Absolutely love the case !!          3          3
# 13   Best Rechargeable Battery Case on the Market!!...         12         16
# 16                                SUPER DUPER QUALITY!          2          3
# 18                             High power as promised!          2          3
# 27                          Solid Charger but RF noisy          3          4
# 31                                                good          2          3
# 54                                         I recommend          3          3
# 74                           SOOO CUTE AND AFFORDABLE!          2          2
# 88                                   Galaxy S4 Charger          4          4
# 143               Not as nice as I thought it would be          2          3
# 151                                    wife phone case          2          2
# 154                                    It is very cute          2          2
# 155                                          Beautiful          2          2
# 160                                  Excellent Product          2          2
#
#      helpful_ratio  ratio_percent  review_len  IsHelpful  Capslock_Count
# 3         1.000000            100          51          1               1
# 4         0.666667             66          23          0               0
# 5         0.500000             50          23          0               0
# 7         0.500000             50          20          0               0
# 8         0.666667             66          44          0               0
# 11        0.666667             66          71          0               0
# 12        1.000000            100          47          1               3
# 13        0.750000             75         239          1               5
# 16        0.666667             66          46          0               0
# 18        0.666667             66         102          0               0
# 27        0.750000             75          83          1               2
# 31        0.666667             66          30          0               1
# 54        1.000000            100          23          1               0
# 74        1.000000            100          55          1               3
# 88        1.000000            100         171          1               1
# 143       0.666667             66         103          0               7
# 151       1.000000            100          25          1               0
# 154       1.000000            100          29          1               0
# 155       1.000000            100          22          1               0
# 160       1.000000            100          22          1               0

# %%
df['Capslock_Ratio'] = df['Capslock_Count'] / df['review_len']

df['Capslock_Ratio'] = df['Capslock_Ratio'].fillna(0)

df['Capslock_Percent'] = (df['Capslock_Ratio'] * 100).astype(int)
df.head(50)
# Out:
#       helpful                                             Review  Rating  \
# 3      [4, 4]  Item arrived in great time and was in perfect ...       4
# 4      [2, 3]  awesome! stays on, and looks great. can be use...       5
# 5      [1, 2]  These make using the home button easy. My daug...       3
# 7      [1, 2]  it worked for the first week then it only char...       1
# 8      [2, 3]  Good case, solid build. Protects phone all aro...       5
# 11     [2, 3]  This is the first battery case I have had for ...       5
# 12     [3, 3]  Performs exactly as advertised . It's very  st...       5
# 13   [12, 16]  Unlike Most of the Rechargeable Battery cases,...       5
# 16     [2, 3]  It works great. Doesn't heat up like crazy lik...       5
# 18     [2, 3]  I have tested this against the griffin dual ou...       5
# 27     [3, 4]  This is a nice charger but you can tell it was...       4
# 31     [2, 3]  I've bough a munch of different things like th...       5
# 54     [3, 3]  I love this case! It's so pretty.And I love th...       5
# 74     [2, 2]  This is the cutest case EVER!  I love it becau...       5
# 88     [4, 4]  This Charger is awesome! First of all I wasn't...       5
# 143    [2, 3]  In a nutshell, this is NOT an OEM charger.  Al...       1
# 151    [2, 2]  Bought one for me and another for the wife. Ac...       5
# 154    [2, 2]  I was surprised it game in three steps, but wh...       5
# 155    [2, 2]  I was looking for something different to my wi...       5
# 160    [2, 2]  Great case for my phone. Protects and keeps me...       5
# 161    [3, 3]  Other power cases muffled the speaker sound. T...       5
# 165    [2, 2]  Bought one for me and the wife (diff color;pho...       5
# 167    [1, 4]  couldnt watch movies on the htc without the ba...       5
# 168    [0, 3]  This product is great. I like the kickstand on...       5
# 169    [0, 2]  Not Many HTC one battery cases for sale and th...       5
# 170  [11, 11]  I never do this, but I almost bought this prod...       1
# 171    [0, 2]  This is absolutely amazing, more than doubles ...       5
# 172    [1, 5]  Bought case for me and wife to qualify for fre...       5
# 173    [0, 3]  Since I am always on my phone, the battery lif...       5
# 175    [0, 3]  My brother just got the HTC One, and I promise...       5
# 176    [0, 3]  The color pops out so well. Clips well to my p...       5
# 177    [0, 3]  The raised edges protect the screens from fall...       5
# 178    [0, 3]  fits well on the phone and it is easy to use. ...       5
# 179    [0, 3]  The S5 is a fantastic phone. However because o...       5
# 180    [0, 3]  Totally worth the money, It protects my phone ...       5
# 181    [0, 3]  I got this case for my nephew, and he claims t...       5
# 182    [0, 4]  This is a really great case, looks and feels a...       5
# 183    [0, 3]  I think this case is an excellent choice, sinc...       5
# 188  [25, 25]  Bought this for my new AT&T; Galaxy SII, the c...       5
# 189    [1, 2]  I liked the case, and for the amount of money ...       5
# 190    [0, 2]  I bought this for the at&t samsung galaxy s2 a...       2
# 196    [1, 3]  Don't expect more but it works well for the re...       5
# 210  [20, 24]  A note of caution from someone who owned and u...       3
# 219    [4, 4]  I bought this recently and did not expect much...       5
# 220    [4, 4]  A good inexpensive cable that works like the o...       5
# 226    [2, 2]  we bought this charging cord because the t505 ...       5
# 227  [14, 22]  It's true! This cable outperforms the original...       5
# 249  [10, 11]  Works fine IF you don't move the phone.  If yo...       3
# 265    [5, 5]  was somewhat concerned after reading some of t...       5
# 278    [9, 9]  This power cord is a great replacement for the...       5
#
#                                                  Title  helpful_0  helpful_1  \
# 3                                                Cute!          4          4
# 4            leopard home button sticker for iphone 4s          2          3
# 5                                                 Cute          1          2
# 7                                      not a good Idea          1          2
# 8                                           Solid Case          2          3
# 11                                            A Winner          2          3
# 12                         Absolutely love the case !!          3          3
# 13   Best Rechargeable Battery Case on the Market!!...         12         16
# 16                                SUPER DUPER QUALITY!          2          3
# 18                             High power as promised!          2          3
# 27                          Solid Charger but RF noisy          3          4
# 31                                                good          2          3
# 54                                         I recommend          3          3
# 74                           SOOO CUTE AND AFFORDABLE!          2          2
# 88                                   Galaxy S4 Charger          4          4
# 143               Not as nice as I thought it would be          2          3
# 151                                    wife phone case          2          2
# 154                                    It is very cute          2          2
# 155                                          Beautiful          2          2
# 160                                  Excellent Product          2          2
# 161                                Speakers Sound Good          3          3
# 165                                      charging case          2          2
# 167                                 Just what i needed          1          4
# 168                    Puts a new perspective on power          0          3
# 169                          Fit well om my GF's phone          0          2
# 170  Almost every positive review posted for this p...         11         11
# 171                     Amazing Case, SAVED MY LIFE!!!          0          2
# 172                           case and charger in one.          1          5
# 173                                           Finally!          0          3
# 175           yet another awesome case from these guys          0          3
# 176                                          Sweeeeeet          0          3
# 177                                              BOMBA          0          3
# 178                                    nice blue color          0          3
# 179                                 Powered to the max          0          3
# 180                              MUST GET GUYS REALLY!          0          3
# 181                            Additional battery life          0          3
# 182                                       I Love this!          0          4
# 183                          One of the few that works          0          3
# 188                         Awesome case and cheap too         25         25
# 189                Good case, flexible but good enough          1          2
# 190                        Don't get this for the SGS2          0          2
# 196                      GOOD CASE for the Worth of 4$          1          3
# 210  Generic USB 2.0 cable, will work with a Blackb...         20         24
# 219                          CHEAP and works perfectly          4          4
# 220                                   Good for the car          4          4
# 226                                   does as expected          2          2
# 227                                           Perfect!         14         22
# 249                       Mediocre, even for the price         10         11
# 265                                  would order again          5          5
# 278                  Perfect for my T-Mobile Galaxy S2          9          9
#
#      helpful_ratio  ratio_percent  review_len  IsHelpful  Capslock_Count  \
# 3         1.000000            100          51          1               1
# 4         0.666667             66          23          0               0
# 5         0.500000             50          23          0               0
# 7         0.500000             50          20          0               0
# 8         0.666667             66          44          0               0
# 11        0.666667             66          71          0               0
# 12        1.000000            100          47          1               3
# 13        0.750000             75         239          1               5
# 16        0.666667             66          46          0               0
# 18        0.666667             66         102          0               0
# 27        0.750000             75          83          1               2
# 31        0.666667             66          30          0               1
# 54        1.000000            100          23          1               0
# 74        1.000000            100          55          1               3
# 88        1.000000            100         171          1               1
# 143       0.666667             66         103          0               7
# 151       1.000000            100          25          1               0
# 154       1.000000            100          29          1               0
# 155       1.000000            100          22          1               0
# 160       1.000000            100          22          1               0
# 161       1.000000            100          20          1               0
# 165       1.000000            100          44          1               0
# 167       0.250000             25          40          0               0
# 168       0.000000              0          22          0               0
# 169       0.000000              0          31          0               1
# 170       1.000000            100         145          1               0
# 171       0.000000              0          32          0               1
# 172       0.200000             20          60          0               0
# 173       0.000000              0          29          0               0
# 175       0.000000              0          42          0               2
# 176       0.000000              0          20          0               0
# 177       0.000000              0          21          0               0
# 178       0.000000              0          21          0               0
# 179       0.000000              0          35          0               0
# 180       0.000000              0          30          0               1
# 181       0.000000              0          49          0               0
# 182       0.000000              0          20          0               0
# 183       0.000000              0          77          0               0
# 188       1.000000            100          85          1              14
# 189       0.500000             50          72          0               1
# 190       0.000000              0          78          0               1
# 196       0.333333             33          76          0               1
# 210       0.833333             83         149          1              14
# 219       1.000000            100          94          1               1
# 220       1.000000            100          67          1               1
# 226       1.000000            100          94          1               0
# 227       0.636364             63          79          0               0
# 249       0.909091             90          62          1               1
# 265       1.000000            100          41          1               0
# 278       1.000000            100         199          1               1
#
#      Capslock_Ratio  Capslock_Percent
# 3          0.019608                 1
# 4          0.000000                 0
# 5          0.000000                 0
# 7          0.000000                 0
# 8          0.000000                 0
# 11         0.000000                 0
# 12         0.063830                 6
# 13         0.020921                 2
# 16         0.000000                 0
# 18         0.000000                 0
# 27         0.024096                 2
# 31         0.033333                 3
# 54         0.000000                 0
# 74         0.054545                 5
# 88         0.005848                 0
# 143        0.067961                 6
# 151        0.000000                 0
# 154        0.000000                 0
# 155        0.000000                 0
# 160        0.000000                 0
# 161        0.000000                 0
# 165        0.000000                 0
# 167        0.000000                 0
# 168        0.000000                 0
# 169        0.032258                 3
# 170        0.000000                 0
# 171        0.031250                 3
# 172        0.000000                 0
# 173        0.000000                 0
# 175        0.047619                 4
# 176        0.000000                 0
# 177        0.000000                 0
# 178        0.000000                 0
# 179        0.000000                 0
# 180        0.033333                 3
# 181        0.000000                 0
# 182        0.000000                 0
# 183        0.000000                 0
# 188        0.164706                16
# 189        0.013889                 1
# 190        0.012821                 1
# 196        0.013158                 1
# 210        0.093960                 9
# 219        0.010638                 1
# 220        0.014925                 1
# 226        0.000000                 0
# 227        0.000000                 0
# 249        0.016129                 1
# 265        0.000000                 0
# 278        0.005025                 0
